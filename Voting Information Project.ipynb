# %% [markdown]
# # Voting Information Project

# %% [markdown]
# ## Introduction

# %% [markdown]
# These two CSV files represent fictional addresses of voters and polling places.  The main objective is to merge them into a single table matching addresses to polling places based upon the IDs provided in each table.  Both tables are riddled with data in incorrect columns and inconsistent formats, issues commonly associated with user-submitted data.  Extensive data cleaning is necessary prior to merging the tables and conducting further analysis.

# %% [markdown]
# ## Obtain

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries.

import pandas as pd
import functions as func

# %% [markdown]
# ### Load Data

# %%
# Load addresses data as a DataFrame addresses.
# Load precinct_polling_list data as a DataFrame precincts.

addresses = pd.read_csv('addresses.csv')
precincts = pd.read_csv('precinct_polling_list.csv')

# %% [markdown]
# ### Inspect Data

# %%
# Check to see if addresses and precincts loaded properly.

display(addresses.head())
display(precincts.head())
# Out:
#                       Street  Apt       City State         Zip Precinct ID
# 0              7 BEACON BLVD  NaN    PEABODY    MA  01960-6303     025-090
# 1              1847 TOWER DR  NaN  STOUGHTON    WI  53589-3539     055-015
# 2       4628 GREEN VALLEY RD  NaN  FAIRFIELD    CA  94534-1368     006-009
# 3                14 HALET ST  NaN   PORTLAND    ME  04102-1734     023-089
# 4  1606 BLACKBURN HEIGHTS DR  NaN  SEWICKLEY    PA  15143-8626     042-018
#                           Street        City State/ZIP Country Precinct
# 0                288 York Street   New Haven  CT 06511     USA  CON-069
# 1  301-399 South Boulevard Drive  Bainbridge  GA 39819     USA  GEO-062
# 2         150-151 Tremont Street      Boston  MA 02111     USA  MAS-111
# 3          2395 Ingleside Avenue       Macon  GA 31204     USA  GEO-041
# 4           1007 Merchant Street    Ambridge  PA 15003     USA  MAS-018

# %%
# Check addresses and precincts index dtype and column dtypes, non-null values
# and memory usage.

print(addresses.info())
print()
print(precincts.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 6 columns):
# Street         41 non-null object
# Apt            2 non-null object
# City           41 non-null object
# State          41 non-null object
# Zip            41 non-null object
# Precinct ID    41 non-null object
# dtypes: object(6)
# memory usage: 2.0+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 5 columns):
# Street       33 non-null object
# City         33 non-null object
# State/ZIP    33 non-null object
# Country      31 non-null object
# Precinct     29 non-null object
# dtypes: object(5)
# memory usage: 1.4+ KB
# None

# %% [markdown]
# ## Scrub

# %% [markdown]
# ### Split State/Zip

# %%
# In precincts, the column State/ZIP contains state abbreviations and zip codes
# separated by a space.
# This column will be separated into two different columns (State and Zip) on
# the space for easier data handling.
# After the column split, State/ZIP will be removed from precincts.

precincts[['State', 'Zip']] = precincts['State/ZIP'].str.split(' ', \
                                                               expand=True)
precincts = precincts.drop(columns='State/ZIP')

# %%
# Check to see State and Zip have been added and State/ZIP removed.

precincts.head()
# Out:
#                           Street        City Country Precinct State    Zip
# 0                288 York Street   New Haven     USA  CON-069    CT  06511
# 1  301-399 South Boulevard Drive  Bainbridge     USA  GEO-062    GA  39819
# 2         150-151 Tremont Street      Boston     USA  MAS-111    MA  02111
# 3          2395 Ingleside Avenue       Macon     USA  GEO-041    GA  31204
# 4           1007 Merchant Street    Ambridge     USA  MAS-018    PA  15003

# %% [markdown]
# ### Check Null Values

# %%
# Check addresses and precincts for null values.

print(addresses.isnull().any())
print()
print(precincts.isnull().any())
display(precincts[precincts.isnull().any(axis=1)])
# Out:
# Street         False
# Apt             True
# City           False
# State          False
# Zip            False
# Precinct ID    False
# dtype: bool
#
# Street      False
# City        False
# Country      True
# Precinct     True
# State       False
# Zip          True
# dtype: bool
#                                        Street                City   Country  \
# 6     974 Great Plain Avenue Needham MA 02492                 USA       NaN
# 13                           29 Godwin Avenue  Ridgewood NJ 07450  NEWJ-000
# 23  1782 Massachusetts Ave Cambridge MA 02140                 USA       NaN
# 30        2035 East North Avenue Milwaukee WI               53211   WIS-067
#
#    Precinct    State   Zip
# 6       NaN  MAS-006  None
# 13      NaN      USA  None
# 23      NaN  MAS-070  None
# 30      NaN      USA  None

# %% [markdown]
# ### Handling Null Values

# %%
# Check precincts for null values returned four cases.
# Under further inspection, data was entered in incorrect fields causing the
# null values.
# (i.e., address, state, and zip all in the column Street)
# Reference each case by index number using iloc and column name to modify data
# fields.

precincts.iloc[6]['Street'] = '974 Great Plain Avenue'
precincts.iloc[6]['City'] = 'Needham'
precincts.iloc[6]['Country'] = 'USA'
precincts.iloc[6]['Precinct'] = 'MAS-006'
precincts.iloc[6]['State'] = 'MA'
precincts.iloc[6]['Zip'] = '02492'

precincts.iloc[13]['Street'] = '29 Godwin Avenue'
precincts.iloc[13]['City'] = 'Ridgewood'
precincts.iloc[13]['Country'] = 'USA'
precincts.iloc[13]['Precinct'] = 'NEWJ-000'
precincts.iloc[13]['State'] = 'NJ'
precincts.iloc[13]['Zip'] = '07450'

precincts.iloc[23]['Street'] = '1782 Massachusetts Ave'
precincts.iloc[23]['City'] = 'Cambridge'
precincts.iloc[23]['Country'] = 'USA'
precincts.iloc[23]['Precinct'] = 'MAS-070'
precincts.iloc[23]['State'] = 'MA'
precincts.iloc[23]['Zip'] = '02140'

precincts.iloc[30]['Street'] = '2035 East North Avenue'
precincts.iloc[30]['City'] = 'Milwaukee'
precincts.iloc[30]['Country'] = 'USA'
precincts.iloc[30]['Precinct'] = 'WIS-067'
precincts.iloc[30]['State'] = 'WI'
precincts.iloc[30]['Zip'] = '53211'

# %%
# Check to see if addresses have been amended properly.

display(precincts[precincts.index == 6])
display(precincts[precincts.index == 13])
display(precincts[precincts.index == 23])
display(precincts[precincts.index == 30])
# Out:
#                    Street     City Country Precinct State    Zip
# 6  974 Great Plain Avenue  Needham     USA  MAS-006    MA  02492
#               Street       City Country  Precinct State    Zip
# 13  29 Godwin Avenue  Ridgewood     USA  NEWJ-000    NJ  07450
#                     Street       City Country Precinct State    Zip
# 23  1782 Massachusetts Ave  Cambridge     USA  MAS-070    MA  02140
#                     Street       City Country Precinct State    Zip
# 30  2035 East North Avenue  Milwaukee     USA  WIS-067    WI  53211

# %% [markdown]
# ### Composite Key Introduction

# %% [markdown]
# The goal of this project is to merge addresses and precincts into a single table matching addresses to polling places.  The best way to do this is by creating a new ID (End ID) that matches the three digits following the hyphen in the Precinct ID column in the addresses table to the three digits following the hyphen in the Precinct column in the precincts table.  Because these three digits could be identical from one precinct to another, it will be necessary for a secondary identifier to be used, the column State.  A combination of two columns in one table used to uniquely identify is known as a composite key.

# %% [markdown]
# ### Unique States (First Part of Composite Key)

# %%
# Check if amount of unique states differ between addresses and precincts.

print(sorted(addresses['State'].unique()))
print()
print(addresses['State'].nunique())
print()
print(sorted(precincts['State'].unique()))
print()
print(precincts['State'].nunique())
# Out:
# ['AZ', 'CA', 'CT', 'FL', 'GA', 'IL', 'MA', 'ME', 'MN', 'NJ', 'NY', 'PA', 'VA', 'WI']
#
# 14
#
# ['AZ', 'CA', 'CT', 'FL', 'GA', 'IL', 'MA', 'ME', 'MN', 'NJ', 'NY', 'PA', 'VA', 'WI']
#
# 14

# %% [markdown]
# ### Adding End ID (Second Part of Composite Key)

# %%
# Create a new column End ID containing the last three digits of Precinct ID in
# addresses.
# Create a new column End ID containing the last three digits of Precinct in
# precincts.
# Create a new column Begin ID containing the state code of Precinct in
# precincts.
# Begin ID will be used later for checking purposes.

addresses[['remove', 'End ID']] = addresses['Precinct ID'].str.split('-', \
                                                                  expand=True)
addresses = addresses.drop(columns = 'remove')
precincts[['Begin ID', 'End ID']] = precincts['Precinct'].str.split('-', n=1, \
                                                                  expand=True)

# %%
# Check to see if the End ID column in addresses and precincts was added 
# properly.

display(addresses.head())
display(precincts.head())
# Out:
#                       Street  Apt       City State         Zip Precinct ID  \
# 0              7 BEACON BLVD  NaN    PEABODY    MA  01960-6303     025-090
# 1              1847 TOWER DR  NaN  STOUGHTON    WI  53589-3539     055-015
# 2       4628 GREEN VALLEY RD  NaN  FAIRFIELD    CA  94534-1368     006-009
# 3                14 HALET ST  NaN   PORTLAND    ME  04102-1734     023-089
# 4  1606 BLACKBURN HEIGHTS DR  NaN  SEWICKLEY    PA  15143-8626     042-018
#
#   End ID
# 0    090
# 1    015
# 2    009
# 3    089
# 4    018
#                           Street        City Country Precinct State    Zip  \
# 0                288 York Street   New Haven     USA  CON-069    CT  06511
# 1  301-399 South Boulevard Drive  Bainbridge     USA  GEO-062    GA  39819
# 2         150-151 Tremont Street      Boston     USA  MAS-111    MA  02111
# 3          2395 Ingleside Avenue       Macon     USA  GEO-041    GA  31204
# 4           1007 Merchant Street    Ambridge     USA  MAS-018    PA  15003
#
#   Begin ID End ID
# 0      CON    069
# 1      GEO    062
# 2      MAS    111
# 3      GEO    041
# 4      MAS    018

# %% [markdown]
# ### Check State Format

# %%
# Check all states length in States column are two letters in addresses and 
# precincts.
# Check all states contain only letters in States column in addresses and 
# precincts.

print(func.character_length_checker(addresses['State'], 2))
print(addresses['State'].str.isalpha().all())

print(func.character_length_checker(precincts['State'], 2))
print(precincts['State'].str.isalpha().all())
# Out:
# True
# True
# True
# True

# %% [markdown]
# ### Check End ID Format

# %%
# Check all ID lengths in End ID column are three numbers in addresses and 
# precincts.
# Check all IDs contain only numbers in End ID column in addresses and 
# precincts.

print(func.character_length_checker(addresses['End ID'], 3))
print(addresses['End ID'].str.isdigit().all())

print(func.character_length_checker(precincts['End ID'], 3))
print(precincts['End ID'].str.isdigit().all())
# Out:
# True
# True
# True
# False

# %%
# Locate the End ID(s) not containing three numbers in precincts.
# Locate the correct End ID in addresses by searching by state.

display(precincts[~precincts['End ID'].str.isdigit()])
display(addresses[addresses['State'] == 'FL'])
# Out:
#                              Street       City Country Precinct State    Zip  \
# 27  9600-9708 West Linebaugh Avenue  Westchase     USA  FLO--67    FL  33626
#
#    Begin ID End ID
# 27      FLO    -67
#                Street  Apt          City State         Zip Precinct ID End ID
# 6   1011 VALENCIA AVE  NaN  CORAL GABLES    FL  33134-5536     012-051    051
# 19  10338 MILLPORT DR  NaN         TAMPA    FL  33626-1706     012-067    067

# %%
# Change the End ID not containing three numbers in precincts.
# Change the Precinct to the correct ID in precincts.

precincts.iloc[27]['End ID'] = '067'
precincts.iloc[27]['Precinct'] = 'FLO-067'

# %%
# Check to see if addresses have been amended properly.

precincts[(precincts['State'] == 'FL') & (precincts['End ID'] == '067')]
# Out:
#                              Street       City Country Precinct State    Zip  \
# 27  9600-9708 West Linebaugh Avenue  Westchase     USA  FLO-067    FL  33626
#
#    Begin ID End ID
# 27      FLO    067

# %% [markdown]
# ### Merge Addresses and Precincts

# %%
# FROM addresses LEFT JOIN precincts ON State and End ID.
# End ID is no longer needed after the merge.
# Rename the columns by adding suffixes that correspond to the original tables.

addresses_precincts = pd.merge(addresses, precincts, how='left', \
                               on=['State', 'End ID'], \
                               suffixes=['_ADDRESSES', '_PRECINCTS'])
addresses_precincts = addresses_precincts.drop(columns='End ID')
addresses_precincts = addresses_precincts.rename(\
                                columns={'Apt': 'Apt_ADDRESSES', \
                                         'State': 'State_ADDRESSES', \
                                         'Precinct ID': 'Precinct_ID_ADDRESSES', \
                                         'Country': 'Country_PRECINCTS', \
                                         'Precinct': 'Precinct_PRECINCTS', \
                                         'Begin ID': 'Begin_ID_PRECINCTS'})

# %%
# Check to see if join was successful and columns were renamed.

addresses_precincts.head()
# Out:
#             Street_ADDRESSES Apt_ADDRESSES City_ADDRESSES State_ADDRESSES  \
# 0              7 BEACON BLVD           NaN        PEABODY              MA
# 1              1847 TOWER DR           NaN      STOUGHTON              WI
# 2       4628 GREEN VALLEY RD           NaN      FAIRFIELD              CA
# 3                14 HALET ST           NaN       PORTLAND              ME
# 4  1606 BLACKBURN HEIGHTS DR           NaN      SEWICKLEY              PA
#
#   Zip_ADDRESSES Precinct_ID_ADDRESSES       Street_PRECINCTS City_PRECINCTS  \
# 0    01960-6303               025-090   139 Lynnfield Street        Peabody
# 1    53589-3539               055-015       114 State Street        Madison
# 2    94534-1368               006-009  3085 Jefferson Street           Napa
# 3    04102-1734               023-089    574 Congress Street       Portland
# 4    15143-8626               042-018   1007 Merchant Street       Ambridge
#
#   Country_PRECINCTS Precinct_PRECINCTS Zip_PRECINCTS Begin_ID_PRECINCTS
# 0               USA            MAS-090         01960                MAS
# 1               USA            WIS-015         53703                WIS
# 2               USA            CAL-009         94559                CAL
# 3               USA            MAI-089         04101                MAI
# 4               USA            MAS-018         15003                MAS

# %% [markdown]
# ### Precinct Check

# %%
# Get the unique precinct state codes to program in precinct_check function.
# Checks if State_ADDRESSES column corresponds with Begin_ID_PRECINCTS column.

addresses_precincts['Begin_ID_PRECINCTS'] = \
addresses_precincts['Begin_ID_PRECINCTS'].astype(str)
print(sorted(addresses_precincts['Begin_ID_PRECINCTS'].unique()))
print()
print(addresses_precincts['Begin_ID_PRECINCTS'].nunique())
# Out:
# ['ARI', 'CAL', 'CON', 'FLO', 'GEO', 'ILL', 'MAI', 'MAS', 'MIN', 'NEWJ', 'NEWY', 'PEN', 'VIR', 'WIS', 'nan']
#
# 15

# %%
# Run precinct_check and add results to addresses_precincts as Precinct_Check 
# column.

addresses_precincts['Precinct_Check'] = \
addresses_precincts.apply(func.precinct_check, axis=1)

# %%
# One mismatch unrelated to null values was detected.

addresses_precincts[addresses_precincts['Precinct_Check'] == 'Mismatch']
# Out:
#              Street_ADDRESSES Apt_ADDRESSES City_ADDRESSES State_ADDRESSES  \
# 4   1606 BLACKBURN HEIGHTS DR           NaN      SEWICKLEY              PA
# 14           300 CHURCHILL RD           NaN        TEANECK              NJ
# 18          22 PIPING ROCK DR           NaN       OSSINING              NY
# 24           75 HUNTINGTON RD           NaN         NEWTON              MA
# 39         274 CABOT MAIL CTR           NaN      CAMBRIDGE              MA
#
#    Zip_ADDRESSES Precinct_ID_ADDRESSES      Street_PRECINCTS City_PRECINCTS  \
# 4     15143-8626               042-018  1007 Merchant Street       Ambridge
# 14    07666-3007               034-087                   NaN            NaN
# 18    10562-2349               036-000                   NaN            NaN
# 24    02458-2416               025-011                   NaN            NaN
# 39    02138-7535               025-076                   NaN            NaN
#
#    Country_PRECINCTS Precinct_PRECINCTS Zip_PRECINCTS Begin_ID_PRECINCTS  \
# 4                USA            MAS-018         15003                MAS
# 14               NaN                NaN           NaN                nan
# 18               NaN                NaN           NaN                nan
# 24               NaN                NaN           NaN                nan
# 39               NaN                NaN           NaN                nan
#
#    Precinct_Check
# 4        Mismatch
# 14       Mismatch
# 18       Mismatch
# 24       Mismatch
# 39       Mismatch

# %% [markdown]
# After further analysis, the address of the voter and the address of the precinct are located in PA.  Precinct_PRECINCTS is entered as MAS-018.  Unfortunately this corresponds with the state MA.  Therefore the Precinct_PRECINCTS must be amended to PEN-018.

# %%
# Changed from a Massachusetts based precinct to Pennsylvania based precinct.

addresses_precincts.iloc[4]['Precinct_PRECINCTS'] = 'PEN-018'

# %% [markdown]
# ### Final Addresses and Precincts

# %%
# Begin_ID_PRECINCTS is no longer needed after precinct check.
# Final version of addresses_precincts table.

addresses_precincts = addresses_precincts.drop(columns='Begin_ID_PRECINCTS')
addresses_precincts
# Out:
#              Street_ADDRESSES Apt_ADDRESSES City_ADDRESSES State_ADDRESSES  \
# 0               7 BEACON BLVD           NaN        PEABODY              MA
# 1               1847 TOWER DR           NaN      STOUGHTON              WI
# 2        4628 GREEN VALLEY RD           NaN      FAIRFIELD              CA
# 3                 14 HALET ST           NaN       PORTLAND              ME
# 4   1606 BLACKBURN HEIGHTS DR           NaN      SEWICKLEY              PA
# 5               405 LAUREL PL           NaN          MACON              GA
# 6           1011 VALENCIA AVE           NaN   CORAL GABLES              FL
# 7                43 BOYDEN ST           NaN       BROCKTON              MA
# 8          1051 E STEARNS AVE        APT 36       LA HABRA              CA
# 9                10 RUSTIC DR           NaN    N BRUNSWICK              NJ
# 10            719 ROSEWOOD DR           NaN      PALO ALTO              CA
# 11          5373 FOXHOUND WAY           NaN      SAN DIEGO              CA
# 12           2 Gunderson Road           NaN     WILMINGTON              MA
# 13             1272 BEACON ST         APT 1      BROOKLINE              MA
# 14           300 CHURCHILL RD           NaN        TEANECK              NJ
# 15        439 MATHER MAIL CTR           NaN      CAMBRIDGE              MA
# 16          1228 E KRAMER CIR           NaN           MESA              AZ
# 17            5261 LOCHLOY DR           NaN          EDINA              MN
# 18          22 PIPING ROCK DR           NaN       OSSINING              NY
# 19          10338 MILLPORT DR           NaN          TAMPA              FL
# 20          1244 FAIRVIEW AVE           NaN      HAVERTOWN              PA
# 21       193 WINDING RIVER RD           NaN      WELLESLEY              MA
# 22           9650 THACKERY SQ           NaN        FAIRFAX              VA
# 23      390 WINTHROP MAIL CTR           NaN      CAMBRIDGE              MA
# 24           75 HUNTINGTON RD           NaN         NEWTON              MA
# 25              15 HAMPTON DR           NaN     WOODBRIDGE              CT
# 26              19 O KEEFE RD           NaN    BRIDGEWATER              NJ
# 27          49 CLOCK TOWER LN           NaN   OLD WESTBURY              NY
# 28                18 ACORN LN           NaN    SCARBOROUGH              ME
# 29             2835 NORMAN DR           NaN     BROOKFIELD              WI
# 30          17635 FAIRWAY CIR           NaN   MONTE SERENO              CA
# 31                25 DAISY LN           NaN        AMHERST              NY
# 32             107 REGENTS SQ           NaN  PEACHTREE CTY              GA
# 33        725 GARIBALDI ST SW           NaN        ATLANTA              GA
# 34        1006 CREST RIDGE DR           NaN     EAST POINT              GA
# 35           1404 NELSON BLVD           NaN       ROCKFORD              IL
# 36               916 JULIA PL           NaN     BAINBRIDGE              GA
# 37          3375 RILMAN RD NW           NaN        ATLANTA              GA
# 38          37 MORANG COVE RD           NaN      NOBLEBORO              ME
# 39         274 CABOT MAIL CTR           NaN      CAMBRIDGE              MA
# 40               6 FOX RUN LN           NaN     MARBLEHEAD              MA
#
#    Zip_ADDRESSES Precinct_ID_ADDRESSES                 Street_PRECINCTS  \
# 0     01960-6303               025-090             139 Lynnfield Street
# 1     53589-3539               055-015                 114 State Street
# 2     94534-1368               006-009            3085 Jefferson Street
# 3     04102-1734               023-089              574 Congress Street
# 4     15143-8626               042-018             1007 Merchant Street
# 5     31220-8761               013-041            2395 Ingleside Avenue
# 6     33134-5536               012-051            859 Washington Avenue
# 7     02302-2303               025-111           150-151 Tremont Street
# 8     90631-4857               006-021              108 West 2nd Street
# 9     08902-4706               034-010                180 Nassau Street
# 10    94303-3638               006-041               443 Emerson Street
# 11    92130-4834               006-032       563 Carlsbad Village Drive
# 12    01887-1520               048-010                  328 Boston Road
# 13    02446-3717               025-111           150-151 Tremont Street
# 14    07666-3007               034-087                              NaN
# 15    02138-7570               025-070           1782 Massachusetts Ave
# 16    85203-1941               004-067        1149 East Southern Avenue
# 17    55436-2023               027-028             210 Blake Road North
# 18    10562-2349               036-000                              NaN
# 19    33626-1706               012-067  9600-9708 West Linebaugh Avenue
# 20    19083-4219               042-097            2313 Frankford Avenue
# 21    02482-7319               025-006           974 Great Plain Avenue
# 22    22032-2537               051-092          1101 South Joyce Street
# 23    02138-7578               025-070           1782 Massachusetts Ave
# 24    02458-2416               025-011                              NaN
# 25    06525-1540               009-069                  288 York Street
# 26    08807-5694               034-010                180 Nassau Street
# 27    11568-1031               036-099             2048 Hillside Avenue
# 28    04074-7518               023-089              574 Congress Street
# 29    53045-3015               055-067           2035 East North Avenue
# 30    95030-2212               006-000         1875 South Bascom Avenue
# 31    14228-1262               036-072            5110-5140 Main Street
# 32    30269-4279               013-009             6444-6544 Georgia 85
# 33    30310-2170               013-000   1093 Hemphill Avenue Northwest
# 34    30344-5764               013-055    484 Moreland Avenue Northeast
# 35    61104-4718               017-038            311 East State Street
# 36    39819-4816               013-062    301-399 South Boulevard Drive
# 37    30327-1507               013-000   1093 Hemphill Avenue Northwest
# 38    04555-9506               023-027              110 Community Drive
# 39    02138-7535               025-076                              NaN
# 40    01945-2169               025-090             139 Lynnfield Street
#
#    City_PRECINCTS Country_PRECINCTS Precinct_PRECINCTS Zip_PRECINCTS  \
# 0         Peabody               USA            MAS-090         01960
# 1         Madison               USA            WIS-015         53703
# 2            Napa               USA            CAL-009         94559
# 3        Portland               USA            MAI-089         04101
# 4        Ambridge               USA            PEN-018         15003
# 5           Macon               USA            GEO-041         31204
# 6     Miami Beach               USA            FLO-051         33139
# 7          Boston               USA            MAS-111         02111
# 8     Los Angeles               USA            CAL-021         90012
# 9       Princeton               USA           NEWJ-010         08542
# 10      Palo Alto               USA            CAL-041         94301
# 11       Carlsbad               USA            CAL-032         92008
# 12      Billerica               USA            MAS-010         01821
# 13         Boston               USA            MAS-111         02111
# 14            NaN               NaN                NaN           NaN
# 15      Cambridge               USA            MAS-070         02140
# 16           Mesa               USA            ARI-067         85204
# 17        Hopkins               USA            MIN-028         55343
# 18            NaN               NaN                NaN           NaN
# 19      Westchase               USA            FLO-067         33626
# 20   Philadelphia               USA            PEN-097         19125
# 21        Needham               USA            MAS-006         02492
# 22      Arlington               USA            VIR-092         22202
# 23      Cambridge               USA            MAS-070         02140
# 24            NaN               NaN                NaN           NaN
# 25      New Haven               USA            CON-069         06511
# 26      Princeton               USA           NEWJ-010         08542
# 27  New Hyde Park               USA           NEWY-099         11040
# 28       Portland               USA            MAI-089         04101
# 29      Milwaukee               USA            WIS-067         53211
# 30       Campbell               USA            CAL-000         95008
# 31        Buffalo               USA           NEWY-072         14221
# 32      Riverdale               USA            GEO-009         30274
# 33        Atlanta               USA            GEO-000         30318
# 34        Atlanta               USA            GEO-055         30307
# 35       Rockford               USA            ILL-038         61104
# 36     Bainbridge               USA            GEO-062         39819
# 37        Atlanta               USA            GEO-000         30318
# 38        Augusta               USA            MAI-027         04330
# 39            NaN               NaN                NaN           NaN
# 40        Peabody               USA            MAS-090         01960
#
#    Precinct_Check
# 0           Match
# 1           Match
# 2           Match
# 3           Match
# 4        Mismatch
# 5           Match
# 6           Match
# 7           Match
# 8           Match
# 9           Match
# 10          Match
# 11          Match
# 12          Match
# 13          Match
# 14       Mismatch
# 15          Match
# 16          Match
# 17          Match
# 18       Mismatch
# 19          Match
# 20          Match
# 21          Match
# 22          Match
# 23          Match
# 24       Mismatch
# 25          Match
# 26          Match
# 27          Match
# 28          Match
# 29          Match
# 30          Match
# 31          Match
# 32          Match
# 33          Match
# 34          Match
# 35          Match
# 36          Match
# 37          Match
# 38          Match
# 39       Mismatch
# 40          Match

# %% [markdown]
# ### Export Addresses and Precincts to CSV

# %%
# Export addresses_precincts to a csv file.

addresses_precincts.to_csv\
(r'/Users/gdesantis7/Downloads/Democracy Works/addresses_precincts.csv', \
 index=False)

# %% [markdown]
# ## Explore

# %% [markdown]
# ### Voter Percentage by State

# %%
# Voter percentage by state.

addresses_precincts['State_ADDRESSES'].value_counts(normalize=True)
# Out:
# MA    0.243902
# GA    0.146341
# CA    0.121951
# ME    0.073171
# NY    0.073171
# NJ    0.073171
# WI    0.048780
# PA    0.048780
# FL    0.048780
# MN    0.024390
# VA    0.024390
# AZ    0.024390
# CT    0.024390
# IL    0.024390
# Name: State_ADDRESSES, dtype: float64
